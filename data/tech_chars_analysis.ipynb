# %%
import pandas as pd

# %%
df = pd.read_excel('Технические характеристики оборудования.xlsx', sheet_name='Структура ОС')

# %%
df.head(20)
# Out:
#    Технологический номер  Код ЮЛ  Код ОП/Филиала  Код подразделения  Код ПУ  \
# 0                      1     1.0             NaN                NaN     NaN
# 1                     11     1.0             1.0                NaN     NaN
# 2                    111     1.0             1.0                1.0     NaN
# 3                    NaN     NaN             NaN                NaN     NaN
# 4                   1111     1.0             1.0                1.0     1.0
# 5               11110010     1.0             1.0                1.0     1.0
# 6               1111000H     1.0             1.0                1.0     1.0
# 7               1111000B     1.0             1.0                1.0     1.0
# 8               1111000I     1.0             1.0                1.0     1.0
# 9               1111000D     1.0             1.0                1.0     1.0
# 10            1111000J-1     1.0             1.0                1.0     1.0
# ...
